# %%
from collections import Counter
from glob import glob
import os

import numpy as np
from scipy.spatial.distance import cosine

import nltk
import re

from gensim.parsing import PorterStemmer
from gensim.models import Word2Vec

import networkx as nx

from matplotlib import colors
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# %%
# Directory with the text files to read in
file_directory = './files/'

# To remove from each document: seperators and dates
seperators = ['________________']
dates = ['January', 'February', 'March', 
         'April', 'May', 'June', 'July', 
         'August', 'September', 'October', 
         'November', 'December', '2017']
remove_list = dates + seperators

# Stop words to remove from sentences
stop_word_list = nltk.corpus.stopwords.words('english')
# Symbols to remove from sentences
removable_symbols = ['[', ']', '(', ')', '-', ',', ':', '.', '–', '~', ';', '’', "'", '"' , '?', '!']

all_ommited = []

def clean_string(string):
    # We do not treat upper and lower case words as unique
    string = string.lower()
    
    for symbol in removable_symbols:
        string = string.replace(symbol, '')
    
    # Matches a single whitespace character like: space, newline, tab, return
    # Replaces with a single space
    string = re.sub('\s+', ' ', string).strip()
    
    # Check for any of the removal phrases
    for ignore_string in remove_list:
        if ignore_string.lower() in string:
            all_ommited.append(string)
            return ''
        
    return string

def clean_document(doc):
    doc = [clean_string(line) for line in doc]
    
    # Remove lines with length less than specified
    minimium_length = 1
    doc = [line for line in doc if len(line) >= minimium_length]
    
    return doc
    
target = 'andy was here'
split_target = target.split(' ')
whitespace_chars = ['\t', '\n', ' ']
white_pace_combos = [u + v for u in whitespace_chars for v in whitespace_chars]
all_whitespace_options = whitespace_chars + white_pace_combos
test_cases = [test_string.join(split_target) for test_string in all_whitespace_options]
    
for case_number, test_case in enumerate(test_cases):
    cleaned = clean_string(test_case)
    assert cleaned == target, 'Test case {} was not processed correctly:\nInput:{}\nOutput: {}'.format(
        case_number, test_case, cleaned)

# %% [markdown]
# # Load & Clean files. Inpsect sentences loaded

# %%
documents = []
for file_name in glob(file_directory + '*.txt'):
    print('Reading in file {}'.format(file_name))
    
    with open(file_name, 'r') as file_object:
        text = file_object.readlines()
        text = clean_document(text)
        documents.append(text)
        
        sample_every = 50
        sample_size = 10
        
        print('\nSamples ({} lines every {} lines):\n'.format(sample_size, sample_every))
        print('-'*50)
        print('-'*50 + '\n')

        for line_number in range(0, len(text), sample_every):
            for sample_line in text[line_number : line_number + sample_size]:
                print(sample_line.strip())
            print('\n...\n')
        
        print('-'*50)
        print('-'*50 + '\n'*2)
# Out:
# Reading in file ./files/Haiku Journal.txt
#
# Samples (10 lines every 50 lines):
#
# --------------------------------------------------
# --------------------------------------------------
#
# stopping for a breath
# a rabbit watches each step
# cloudy starless night
# one droplet ripples
# koi glide by stepping stones
# the next droplet
# clear skies on the peak
# monkey and koi kiss
# in murky water
# fallen white petals
#
# ...
#
# blossoms on the trail
# branches hanging overhead
# summer has begun natsumeku
# complimentary dish
# steam rises from my hot plate
# slurping thick noodles
# late dinner for one
# blinding lights
# phone ringing
# clanging chopsticks
#
# ...
#
# odds and evens
# glissando into solo
# trading it right back
# wooden onsen inn
# tea steaming with the breeze
# from open windows
# steep path to the stream
# claimed by a fallen tree
# among the forest
# leaves circling upwards
#
# ...
#
# sending smiles across
# birds fighting for bread
# flying straight towards my head
# flimsy slice hanging
# big bowl of curry
# moving slow in tokyo
# takeshita street
# flooded path
# rain bubbles
# earthy scents rising
#
# ...
#
# overlapping shadows
# from familiar figures
# span the dance floor
# matcha mind
# juggling everything nearby
# can spills midair
# dog by the pit
# sparks pop with
# hot brass air
# in my arm
#
# ...
#
# thunder
# spider twirling
# silk the eye cannot see
# disappears upwards
# sunset haze
# in my window
# rings above the clouds
# juggling along
# the accordion waltz
# pigeons heads bobbing
#
# ...
#
# of bees working
# even my water is hot
# roots bubbling
# through the path
# massage my feet
# wet gravel path
# birds are out
# bathing in puddle
# prancing
# feeding
#
# ...
#
# by falling leaves
# panting
# to catch the bus
# the scent of autumn
# pissing
# feet deep
# in soggy soil
# frigid winds
# black night
# thud
#
# ...
#
# together
# chasing dropped balls
# i lift my face back up
# this is where i want to be
# little leaves
# skidding across the street
# at night
# the sign creaking
# with the wind
# clouds over the moon
#
# ...
#
# --------------------------------------------------
# --------------------------------------------------

# %% [markdown]
# # Check Lines Ommitted

# %%
print('Lines ommitted:')
for sentence in sorted(set(all_ommited)):
    print(sentence)
# Out:
# Lines ommitted:
# ________________
# august 1
# august 10
# august 11
# august 12
# august 13
# august 14
# august 15
# august 16
# august 17
# august 18
# august 19
# august 2
# august 20
# august 21
# august 22
# august 23
# august 24
# august 27 hofgarten
# august 27 near marienplatz
# august 28 karlsplatz stachus
# august 29 deutsches museum
# august 29 englischer garten
# august 29 isar
# august 3
# august 30 nymphenburg botanical garden
# august 4
# august 5
# august 6
# august 7
# august 8
# august 9
# july 1
# july 10
# july 11
# july 12
# july 13
# july 14
# july 15
# july 16
# july 17
# july 18
# july 19
# july 2
# july 20
# july 21
# july 22
# july 23
# july 24
# july 25
# july 26
# july 27
# july 28
# july 29
# july 3
# july 30
# july 31
# july 4
# july 5
# july 6
# july 7
# july 8
# july 9
# june 25th
# june 26th
# june 27
# june 28
# june 29
# june 30
# midnight between august 26 and 27 somewhere over the atlantic
# november 29
# october 11
# october 12
# october 18
# october 29
# october 8
# september 1 augustiner keller
# september 1 neue pinakothek
# september 13
# september 2 olympiaberg
# september 22
# september 28
# september 4
# september 9

# %% [markdown]
# # Tokenize

# %%
def sentence_tokenize(doc):
    """
    Takes a string document and returns a list of lists
    corresponding to tokenized setences    
    """
    sentences = nltk.sent_tokenize(doc) 
    
    sentence_token_list = []
    
    for sentence in sentences:
        sentence_tokenized = nltk.word_tokenize(sentence)
        sentence_tokenized = [word for word in sentence_tokenized if word not in stop_word_list]
        sentence_token_list.append(sentence_tokenized)
    
    return sentence_token_list

# List of all sentences tokenized
corpus = []
for document in documents:
    for line in document:
        sentences = sentence_tokenize(line)
        corpus.extend(sentences)

# %% [markdown]
# # Assess how the Sentence Tokenizer Did

# %%
print('Sampling sentences ({} sentences every {} sentences)'.format(sample_size, sample_every))
print('-'*50)

for sentence_number in range(0, len(corpus), sample_every):
    sentences = corpus[sentence_number: sentence_number + sample_size]
    for sentence in sentences:
        print(' '.join(sentence))
    print('...')

print('-'*50)
# Out:
# Sampling sentences (10 sentences every 50 sentences)
# --------------------------------------------------
# stopping breath
# rabbit watches step
# cloudy starless night
# one droplet ripples
# koi glide stepping stones
# next droplet
# clear skies peak
# monkey koi kiss
# murky water
# fallen white petals
# ...
# blossoms trail
# branches hanging overhead
# summer begun natsumeku
# complimentary dish
# steam rises hot plate
# slurping thick noodles
# late dinner one
# blinding lights
# phone ringing
# clanging chopsticks
# ...
# odds evens
# glissando solo
# trading right back
# wooden onsen inn
# tea steaming breeze
# open windows
# steep path stream
# claimed fallen tree
# among forest
# leaves circling upwards
# ...
# sending smiles across
# birds fighting bread
# flying straight towards head
# flimsy slice hanging
# big bowl curry
# moving slow tokyo
# takeshita street
# flooded path
# rain bubbles
# earthy scents rising
# ...
# overlapping shadows
# familiar figures
# span dance floor
# matcha mind
# juggling everything nearby
# spills midair
# dog pit
# sparks pop
# hot brass air
# arm
# ...
# thunder
# spider twirling
# silk eye see
# disappears upwards
# sunset haze
# window
# rings clouds
# juggling along
# accordion waltz
# pigeons heads bobbing
# ...
# bees working
# even water hot
# roots bubbling
# path
# massage feet
# wet gravel path
# birds
# bathing puddle
# prancing
# feeding
# ...
# falling leaves
# panting
# catch bus
# scent autumn
# pissing
# feet deep
# soggy soil
# frigid winds
# black night
# thud
# ...
# together
# chasing dropped balls
# lift face back
# want
# little leaves
# skidding across street
# night
# sign creaking
# wind
# clouds moon
# ...
# --------------------------------------------------

# %% [markdown]
# # Train Word Vectorizer

# %%
experiment_name = ''

# Parameters
dimension = 100 # If too high, model will overfit
window = 5 # Higher means more context, more assumed about the semantic relationship between words

full_experiment_name = experiment_name + '_dim_{}_win_{}'.format(dimension, window)
model_file_name = './models/' + full_experiment_name + '.p'

train_model = True

if train_model:    
    model = Word2Vec(corpus, 
                     size=dimension, 
                     window=window, 
                     sg=1, # Always 1 for small datasets
                     min_count=2, # Can set higher (3 or 4) for bigger datsets
                     workers=1, # Only need 1
                     iter=50, # Maybe too high (overfitting)
                     batch_words=25 # Maybe too low -- related to learning rate (who knows?)
                    )
    model.save(model_file_name)
    print("Trained & Saved {}".format(full_experiment_name))
else:
    model = Word2Vec.load(model_file_name)
    print("Loaded {}".format(full_experiment_name))
# Out:
# Trained & Saved _dim_100_win_5

# %%
vocab = list(model.wv.vocab.keys())
print('Number of unique words in the vocabulary: {}'.format(len(vocab)))
# Out:
# Number of unique words in the vocabulary: 151

# %% [markdown]
# # Inspect Associations

# %%
test = vocab[:20]

for word in test:
    print('Similar to {}: \n'.format(word))
    for similar in model.most_similar(word)[:5]:
        print(similar[0], round(similar[1], 3))
    print('\n' + '-'*50+'\n')
# Out:
# Similar to stopping:
#
# flames 0.24
# together 0.234
# turtles 0.208
# droplet 0.199
# leaves 0.19
#
# --------------------------------------------------
#
# Similar to breath:
#
# midnight 0.229
# hot 0.22
# dipped 0.19
# gliding 0.169
# sinking 0.169
#
# --------------------------------------------------
#
# Similar to night:
#
# slow 0.284
# balls 0.212
# droplets 0.166
# smiling 0.165
# surface 0.156
#
# --------------------------------------------------
#
# Similar to one:
#
# upwards 0.292
# garden 0.248
# balls 0.239
# tokyo 0.228
# midnight 0.206
#
# --------------------------------------------------
#
# Similar to droplet:
#
# see 0.259
# summer 0.208
# lights 0.206
# stopping 0.199
# school 0.19
#
# --------------------------------------------------
#
# Similar to ripples:
#
# stone 0.304
# train 0.262
# sharing 0.254
# flames 0.234
# slurping 0.228
#
# --------------------------------------------------
#
# Similar to koi:
#
# peak 0.306
# air 0.258
# comes 0.241
# time 0.214
# rabbits 0.208
#
# --------------------------------------------------
#
# Similar to peak:
#
# rabbits 0.317
# koi 0.306
# wiggling 0.273
# head 0.269
# full 0.211
#
# --------------------------------------------------
#
# Similar to water:
#
# leaves 0.306
# strides 0.259
# overhead 0.234
# long 0.188
# left 0.171
#
# --------------------------------------------------
#
# Similar to fallen:
#
# tonight 0.317
# away 0.234
# fish 0.204
# summer 0.203
# head 0.199
#
# --------------------------------------------------
#
# Similar to white:
#
# fades 0.262
# beat 0.252
# smiling 0.215
# dim 0.204
# midnight 0.202
#
# --------------------------------------------------
#
# Similar to petals:
#
# sky 0.261
# fuji 0.249
# leaves 0.247
# air 0.235
# like 0.205
#
# --------------------------------------------------
#
# Similar to bare:
#
# reaching 0.264
# turtles 0.239
# sunset 0.226
# away 0.225
# moment 0.214
#
# --------------------------------------------------
#
# Similar to long:
#
# lights 0.212
# autumn 0.211
# dog 0.211
# forest 0.21
# summer 0.203
#
# --------------------------------------------------
#
# Similar to sky:
#
# comes 0.263
# petals 0.261
# fuji 0.261
# open 0.197
# crab 0.194
#
# --------------------------------------------------
#
# Similar to two:
#
# fall 0.286
# across 0.223
# smiling 0.203
# hum 0.201
# subway 0.178
#
# --------------------------------------------------
#
# Similar to turtles:
#
# scent 0.253
# friends 0.252
# bare 0.239
# stopping 0.208
# rock 0.195
#
# --------------------------------------------------
#
# Similar to moment:
#
# tokyo 0.312
# lights 0.231
# crab 0.215
# bare 0.214
# slow 0.193
#
# --------------------------------------------------
#
# Similar to shell:
#
# puddle 0.307
# little 0.241
# moonlight 0.183
# dog 0.175
# fades 0.171
#
# --------------------------------------------------
#
# Similar to tree:
#
# passing 0.283
# another 0.224
# around 0.218
# lake 0.188
# crab 0.165
#
# --------------------------------------------------

# %% [markdown]
# # Extracts Keywords. Inspect them

# %%
def _get_param_matrices(vocabulary, sentence_terms, shortlist=500):
    """
    Returns
    1. Top N (or less, if vocab is short) most frequent terms as a list
    2. Co-occurence matrix for these terms as a dictionary
    3. Dictionary containing "Pg" (expected probability) for the most frequent terms
    4. Dictionary containing number of terms 'affected' for the most frequent terms
    """
 
    # Figure out top n terms with respect to mere occurences
    n = min(shortlist, len(vocabulary))
    topterms = list(vocabulary.keys())
    topterms.sort(key=lambda x: vocabulary[x], reverse=True)
    topterms = topterms[:n]
 
    # nw maps term to the number of terms it 'affected'
    # (sum of number of terms in all sentences it appears in)
    nw = {}
    
    # Co-occurence values are wrt top terms only
    co_occur = {}
    # Initially, co-occurence matrix is empty
    for x in vocabulary:
        co_occur[x] = [0 for i in range(len(topterms))]
 
    # Iterate over list of all sentences' vocabulary dictionaries
    # Build the co-occurence matrix
    for sentence in sentence_terms:
        total_terms = sum(list(sentence.values()))
        # This list contains the indices of all terms from topterms,
        # that are present in this sentence
        top_indices = []
        # Populate top_indices
        top_indices = [topterms.index(x) for x in sentence
                       if x in topterms]
        # Update nw dict, and co-occurence matrix
        for term in sentence:
            nw[term] = nw.get(term, 0) + total_terms
            for index in top_indices:
                co_occur[term][index] += (sentence[term] *
                                          sentence[topterms[index]])
 
    # Pg is just nw[term] / net_vocab_size
    Pg = {}
    N = sum(list(vocabulary.values()))
    for x in topterms:
        Pg[x] = float(nw[x])/N
 
    return topterms, co_occur, Pg, nw

def get_top_n_terms(vocabulary, sentence_terms, n):
    """
    Returns the top n terms from a block of text, in the form of a list,
    from most important to least.
 
    'vocabulary' should be a dict mapping each term to the number
    of its occurences in the entire text.
    'sentence_terms' should be an iterable of dicts, each denoting the
    vocabulary of the corresponding sentence.
    """
 
    #First compute the matrices
    topterms, co_occur, Pg, nw = _get_param_matrices(vocabulary,
                                                     sentence_terms)
 
    #This dict will map each term to its weightage with respect to the
    #document
    result = {}
 
    N = sum(list(vocabulary.values()))
    #Iterates over all terms in vocabulary
    for term in co_occur:
        term = str(term)
        org_term = str(term)
        for x in Pg:
            #expected_cooccur is the expected cooccurence of term with this
            #term, based on nw value of this and Pg value of the other
            expected_cooccur = nw[term] * Pg[x]
            #Result measures the difference(in no of terms) of expected
            #cooccurence and  actual cooccurence
            result[org_term] = ((co_occur[term][topterms.index(x)] -
                                 expected_cooccur)**2 / float(expected_cooccur))
 
    terms = list(result.keys())
    terms.sort(key=lambda x: result[x],
               reverse=True)
 
    return terms[:n]

# Flatten dataset to perform word analysis across all sentences
full_word_list = []
for sentence in corpus:
    filtered_sentence = [word for word in sentence if word in vocab]
    full_word_list.extend(filtered_sentence)


# Counts all words across sentences
full_vocab_count = Counter(full_word_list)

# Counts co-occurences within sentences to select top terms
sentence_vocab_count_list = []
for sentence in corpus:
    filtered_sentence = [word for word in sentence if word in vocab]
    sentence_vocab_count_list.append(Counter(filtered_sentence))

NUM_WORDS = 50
top_terms = get_top_n_terms(full_vocab_count, sentence_vocab_count_list, n=NUM_WORDS)

# %%
# Filter words above manually
# Some words are just uninteresting, even though they are common and effect a lot of other surrounding words
# I often remove ambiguous words that were not learned properly by Word2Vec / don't fit well in the mindmap
uninteresting_string = 'one two three like hanging another would across around back left right summer fall autumn'
uninteresting_words = [word.lower() for word in uninteresting_string.split()]

refined_top_terms = [t for t in top_terms if t not in uninteresting_words]
for top_term in refined_top_terms:
    print(top_term)
# Out:
# faster
# night
# rain
# air
# ripples
# fallen
# together
# tree
# silent
# long
# time
# leaves
# wet
# white
# last
# birds
# friends
# water
# moment
# lights
# path
# window
# high
# full
# clouds
# hands
# street
# tea
# subway
# sharing
# petals
# wind
# branches
# thick
# strides
# arc
# head
# away
# juggling
# towards
# moon
# feet
# moss

# %% [markdown]
# # Form Network

# %%
def build_mind_map(model, root, nodes, alpha):
    """
    Returns the Mind-Map in the form of a NetworkX Graph instance.
 
    model should be an instance of gensim.models.Word2Vec 
    nodes should be a list of terms, included in the vocabulary of model
    root should be the node that is to be used as the root of the Mind Map graph
    """
    g = nx.Graph()
 
    for node in nodes:
        if node not in vocab:
            raise ValueError(node + " not in vocabulary")
    root = root.lower()
    if root not in nodes:
        raise ValueError("root not in nodes")
 
    # Initially, all nodes are unvisited
    unvisited_nodes = set(nodes)
    visited_nodes = set([])
    
    # Maps a visited node to its contextual vector
    visited_node_vectors = {}
    
    # Maps unvisited nodes to their closest neighbor within the visited nodes
    node_distances = {}
 
    # Initialization with respect to root
    current_node = root
    visited_node_vectors[root] = model[root]
    unvisited_nodes.remove(root)
    visited_nodes.add(root)
 
    for i in range(1, len(nodes)):
        # For every unvisited node 'x'
        for x in unvisited_nodes:
            # Compute contextual distance between current node and x
            dist_from_current = cosine(visited_node_vectors[current_node], model[x])
            
            # Compute the minimum contextual distance for x
            distance = node_distances.get(x, (100, ''))
            
            # If current node provides a shorter path to x, 
            # update x's closest node in node_distances
            if distance[0] > dist_from_current:
                node_distances[x] = (dist_from_current, current_node)
 
        # Select the node with the smallest distance to other visited nodes
        next_node = min(unvisited_nodes, key=lambda x: node_distances[x][0])
        
        # Update all containers
        parent = node_distances[next_node][1]
        print("{} --> {}".format(parent, next_node))
        del node_distances[next_node]
        
        next_node_vect = (1 - alpha) * model[next_node] + alpha * visited_node_vectors[parent]
        
        visited_node_vectors[next_node] = next_node_vect
        unvisited_nodes.remove(next_node)
        visited_nodes.add(next_node)
 
        # Add the link between newly selected node and its parent
        g.add_edge(parent.capitalize(), next_node.capitalize())
        current_node = next_node
 
    return g

# %%
MIXING_LEVEL = 0.0
G = build_mind_map(model=model, root=refined_top_terms[0], nodes=refined_top_terms, alpha=MIXING_LEVEL)
# Out:
# faster --> away
# away --> fallen
# fallen --> head
# head --> towards
# fallen --> long
# long --> lights
# lights --> moment
# long --> thick
# thick --> last
# thick --> feet
# long --> leaves
# leaves --> water
# water --> strides
# leaves --> petals
# petals --> air
# air --> branches
# strides --> wet
# branches --> time
# branches --> ripples
# ripples --> sharing
# long --> white
# white --> path
# ripples --> full
# white --> window
# window --> hands
# hands --> juggling
# path --> tea
# tea --> high
# tea --> silent
# silent --> arc
# high --> together
# tea --> rain
# wet --> moss
# window --> birds
# rain --> subway
# head --> moon
# tea --> street
# branches --> tree
# fallen --> friends
# away --> wind
# lights --> clouds
# clouds --> night

# %% [markdown]
# # Visualize Network

# %%
def plot_network(G, pos, color_list, x_lim, y_lim, save=False, name=None):    
    # Draw the nodes and labels
    # Tinkering with the node and font size yielded the below result
    nx.draw_networkx_nodes(G, pos=pos, node_color=color_list, node_size=NODE_SIZE, alpha=ALPHA)
    nx.draw_networkx_labels(G, pos=pos, font_size=FONT_SIZE)

    # Increase size of plot to reduce overlap of text
    params = plt.gcf()
    plSize = params.get_size_inches()
    params.set_size_inches((plSize[0]*SCALE_UP, plSize[1]*SCALE_UP))
    
    # Turn off axis ticks and labels
    plt.tick_params(axis='both', which='both', top='off', right='off', bottom='off', left='off',    
        labelbottom='off', labelleft='off', labeltop='off', labelright='off')
    
    plt.xlim(x_lim)
    plt.ylim(y_lim)
    
    if save:
        save_down = plt.savefig(name)
        print('Saved!')

# %%
def get_colors(G, cmap):
    # For coloration, find the centrallness of a node based on average hops to other nodes
    centralness = nx.closeness_centrality(G)

    # Create a normalized color map space, bounded by the min and max centrality
    # If desired, add slack so central and ending nodes are not so extreme on the color map
    central_values = list(centralness.values())
    ## Sensitive to the color map at hand
    max_centrality = max(central_values) * 1.25 
    min_centrality = min(central_values) * 0.825
    norm = colors.Normalize(vmin=min_centrality, vmax=max_centrality)

    m = cm.ScalarMappable(norm=norm, cmap=cmap)
    color_list = [m.to_rgba(centralness[node]) for node in G]
    
    return color_list
    
# Check out color map options: https://matplotlib.org/examples/color/colormaps_reference.html
# My current favourites: ocean, brg, GnBu
color_list = get_colors(G, cmap = cm.GnBu)

# %%
def get_spatial_layout(G):
    # Find a spring layout for the node positions
    # Set iterations much higher than 50 due to the difficulty of fitting all words
    pos = nx.spring_layout(G, iterations=250)

    # Find maximum and minimum x, y values based on spring layout
    min_y, max_y, min_x, max_x = 0, 0, 0, 0
    
    for value in pos.values():
        if max_x < value[0]:
            max_x = value[0]
        elif min_x > value[0]:
            min_x = value[0]
        if max_y < value[1]:
            max_y = value[1]
        elif min_y > value[1]:
            min_y = value[1]

    extend_ratio = 1.25
    x_lim = [extend_ratio * min_x, extend_ratio * max_x]
    y_lim =[extend_ratio * min_y, extend_ratio * max_y]
    
    return pos, x_lim, y_lim

pos, x_lim, y_lim = get_spatial_layout(G)

# %%
NODE_SIZE = 7000
FONT_SIZE = 12
ALPHA = 0.275 # Needs to be changed depending on color map
SCALE_UP = 3.25

plot_network(G, pos, color_list, x_lim, y_lim, save=False)
print('')

# %%
# Whatever comes to mind
title = 'Sharing Time Full Ripples Tree Branches'

# %%
# Save it down
FIGURE_FOLDER = './pictures/' + full_experiment_name + '/'
if not(os.path.isdir(FIGURE_FOLDER)):
    os.mkdir(FIGURE_FOLDER)

FIGURE_NAME = FIGURE_FOLDER + '{} (mixing={}).png'.format(title, MIXING_LEVEL)

# plot_network(G, pos, color_list, x_lim, y_lim, save=True, name=FIGURE_NAME)
